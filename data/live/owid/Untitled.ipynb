# %%
import datetime
import pandas as pd
import ast
import numpy as np
from scipy.spatial import distance
from tslearn.metrics import dtw,lcss

# %%
def advancedfilters(cube,minPopulation,continentCheck,startDate,endDate):
    cube.fillna(0,inplace=True)
    dropped = []
    for i in range(1,len(cube.columns)):
        if(cube.iloc[-1][i] not in continentCheck or int(float(cube.iloc[-2][i])) <= minPopulation):
            dropped.append(cube.columns[i])
    cube.drop(columns=dropped,inplace=True)        
    cube.drop(cube.tail(2).index,inplace=True)
    cube.set_index(cube.columns[0],inplace=True)
    cube.index = pd.to_datetime(cube.index)
    cube = cube.loc[startDate:endDate]
    cube.index.names = ['Date']
    return cube

def slicer(cube,indicator):
    for i in cube.columns:
        for j in range(len(cube)):
            try:
                cube[i].iloc[j] = ast.literal_eval(cube[i].iloc[j])[indicator]
            except:
                continue
    return cube

def time_series(a,period):
    count = period - 1 
    temp_lst = []
    master_lst = []
    column_names = []
    all_lst = []
    for i in a.columns: 
        for k in range(count,len(a)):
            while count >= 0: 
                temp_lst.append(a[i][k-count])
                count = count-1
            master_lst.append(temp_lst)
            column_names.append(a.index[k])
            count = period-1
            temp_lst = []
        column_label = i 
        temp_sr = pd.Series(master_lst,column_names)
        temp_df = pd.DataFrame(data = temp_sr,columns=[column_label])
        all_lst.append(temp_df)
   
        master_lst = []
        column_names = []
        master = pd.concat(all_lst,axis=1)
    return master


def distfunc(target,comp,method):
    target = np.array(target)
    comp = np.array(comp)
    if method == 'euclidean': 
        return distance.euclidean(target,comp)
    if method == 'manhattan':
        return distance.manhattan(target,comp) 
    if method == 'chebyshev':
        return distance.chebyshev(target,comp)
    if method == 'dtw':
        return dtw(target,comp)
    if method == "lcs":
        return 1-lcss(target,comp)
    
def ranker(cube,target_country,target_date,method,top_n):
    target_identifier = target_country + ' ' + datetime.datetime.strftime(target_date,"%Y-%m-%d")
    identifier = []
    comp_values = []
    result =[]
    for i in cube.columns:
        for j in cube.index:
            if i != target_country:
                identifier.append(i + ' ' + datetime.datetime.strftime(j,"%Y-%m-%d"))
                comp_values.append(distfunc(cube[target_country][target_date],cube[i][j],method))

    for i in np.argsort(comp_values)[:top_n].tolist():
        result.append(identifier[i])
    
    return result

def firstRunOutput(cube,targetCountry,firstDate,lastDate,indicator,method,numberOfResults,minPopulation,startDate,endDate,continentCheck):
    cube_filtered = advancedfilters(cube,minPopulation,continentCheck,startDate,endDate)
    sliced = slicer(cube_filtered,indicator)
    sliced = time_series(sliced,(lastDate-firstDate).days)
    result = ranker(sliced,targetCountry,datetime.datetime(lastDate.year,lastDate.month,lastDate.day),method,numberOfResults)
    master_dict = dict()
    for i in result:
        vec = sliced[i.split()[0]][i.split()[1]]
        date = pd.date_range(end=i.split()[1],start=datetime.datetime.strptime(i.split()[1],"%Y-%m-%d") - datetime.timedelta(days=(lastDate-firstDate).days-1))
        dict_sample = dict(zip(date,vec))
        master_dict[i]=dict_sample
    return master_dict

# %%
###input sample from the front end###

targetCountry =  "Germany"
firstDate = datetime.date(2021,3,5)
lastDate =  datetime.date(2021,3,26) 
indicator =  "biweekly_cases_per_million"
method  = "dtw"

numberOfResults = 10
minPopulation = 500000 
startDate = datetime.date(2021,1,1) 
endDate = datetime.date(2021,8,1) 
continentCheck = ["Europe"]

# %%
cube = pd.read_csv('cube.csv',parse_dates=True)
cube["United Kingdom"].iloc[1]
# Out:
# "{'total_cases': 2662703.0, 'new_cases': 55157.0, 'total_deaths': 75137.0, 'new_deaths': 455.0, 'total_cases_per_million': 39223.0, 'new_cases_per_million': 812.0, 'total_deaths_per_million': 1107.0, 'new_deaths_per_million': 7.0, 'icu_patients': 2420.0, 'icu_patients_per_million': 36.0, 'hosp_patients': 29033.0, 'hosp_patients_per_million': 428.0, 'weekly_icu_admissions': 0.0, 'weekly_icu_admissions_per_million': 0.0, 'weekly_hosp_admissions': 23064.0, 'weekly_hosp_admissions_per_million': 340.0, 'new_tests': 416962.0, 'total_tests': 46247813.0, 'total_tests_per_thousand': 681.0, 'new_tests_per_thousand': 6.0, 'positive_rate': 0.0, 'tests_per_case': 8.0, 'tests_units': 'tests performed', 'total_vaccinations': 1380430.0, 'people_vaccinated': 1380430.0, 'people_fully_vaccinated': 0.0, 'new_vaccinations': 0.0, 'total_vaccinations_per_hundred': 2.0, 'people_vaccinated_per_hundred': 2.0, 'people_fully_vaccinated_per_hundred': 0.0, 'stringency_index': 80.0, 'weekly_cases': 367471.0, 'biweekly_cases': 616539.0, 'weekly_cases_per_million': 5413.0, 'biweekly_cases_per_million': 9082.0, 'weekly_cases_rate': 32.0, 'biweekly_cases_rate': 48.0, 'weekly_deaths': 4277.0, 'biweekly_deaths': 7634.0, 'weekly_deaths_per_million': 63.0, 'biweekly_deaths_per_million': 112.0, 'weekly_deaths_rate': 22.0, 'biweekly_deaths_rate': 19.0}"

# %%
out = firstRunOutput(cube,targetCountry,firstDate,lastDate,indicator,method,numberOfResults,minPopulation,startDate,endDate,continentCheck)
# Out:
# /Users/tunagonen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
out
# Out:
# {'Bulgaria 2021-02-28': {Timestamp('2021-02-08 00:00:00', freq='D'): 1332.672,
#   Timestamp('2021-02-09 00:00:00', freq='D'): 1388.0810000000001,
#   Timestamp('2021-02-10 00:00:00', freq='D'): 1433.415,
#   Timestamp('2021-02-11 00:00:00', freq='D'): 1506.8120000000001,
#   Timestamp('2021-02-12 00:00:00', freq='D'): 1545.8139999999999,
#   Timestamp('2021-02-13 00:00:00', freq='D'): 1568.409,
#   Timestamp('2021-02-14 00:00:00', freq='D'): 1573.158,
#   Timestamp('2021-02-15 00:00:00', freq='D'): 1607.122,
#   Timestamp('2021-02-16 00:00:00', freq='D'): 1662.0980000000002,
#   Timestamp('2021-02-17 00:00:00', freq='D'): 1737.943,
#   Timestamp('2021-02-18 00:00:00', freq='D'): 1767.1580000000001,
#   Timestamp('2021-02-19 00:00:00', freq='D'): 1846.7440000000001,
#   Timestamp('2021-02-20 00:00:00', freq='D'): 1854.66,
#   Timestamp('2021-02-21 00:00:00', freq='D'): 1861.1360000000002,
#   Timestamp('2021-02-22 00:00:00', freq='D'): 1977.708,
#   Timestamp('2021-02-23 00:00:00', freq='D'): 2062.331,
#   Timestamp('2021-03-17 00:00:00', freq='D'): 2217.881,
#   Timestamp('2021-03-18 00:00:00', freq='D'): 2346.984,
#   Timestamp('2021-03-19 00:00:00', freq='D'): 2474.1369999999997},
#  'Norway 2021-03-29': {Timestamp('2021-03-09 00:00:00', freq='D'): 1353.1960000000001,
#   Timestamp('2021-03-10 00:00:00', freq='D'): 1416.65,
#   Timestamp('2021-03-11 00:00:00', freq='D'): 1475.862,
#   Timestamp('2021-03-12 00:00:00', freq='D'): 1546.141,
#   Timestamp('2021-03-13 00:00:00', freq='D'): 1655.341,
#   Timestamp('2021-03-14 00:00:00', freq='D'): 1740.192,
#   Timestamp('2021-03-15 00:00:00', freq='D'): 1765.279,
#   Timestamp('2021-03-16 00:00:00', freq='D'): 1885.3629999999998,
#   Timestamp('2021-03-17 00:00:00', freq='D'): 1954.535,
#   Timestamp('2021-03-18 00:00:00', freq='D'): 2040.124,
#   Timestamp('2021-03-19 00:00:00', freq='D'): 2095.278,
#   Timestamp('2021-03-20 00:00:00', freq='D'): 2179.576,
#   Timestamp('2021-03-21 00:00:00', freq='D'): 2212.963,
#   Timestamp('2021-03-22 00:00:00', freq='D'): 2262.398,
#   Timestamp('2021-03-23 00:00:00', freq='D'): 2330.833,
#   Timestamp('2021-03-24 00:00:00', freq='D'): 2385.9860000000003,
#   Timestamp('2021-03-25 00:00:00', freq='D'): 2378.4230000000002,
#   Timestamp('2021-03-26 00:00:00', freq='D'): 2409.228,
#   Timestamp('2021-03-27 00:00:00', freq='D'): 2336.92,
#   Timestamp('2021-03-28 00:00:00', freq='D'): 2344.483,
#   Timestamp('2021-03-29 00:00:00', freq='D'): 2367.356},
#  'Greece 2021-03-08': {Timestamp('2021-02-16 00:00:00', freq='D'): 1457.249,
#   Timestamp('2021-02-17 00:00:00', freq='D'): 1419.257,
#   Timestamp('2021-02-18 00:00:00', freq='D'): 1451.014,
#   Timestamp('2021-02-19 00:00:00', freq='D'): 1476.2469999999998,
#   Timestamp('2021-02-20 00:00:00', freq='D'): 1506.756,
#   Timestamp('2021-02-21 00:00:00', freq='D'): 1521.243,
#   Timestamp('2021-02-22 00:00:00', freq='D'): 1544.365,
#   Timestamp('2021-02-23 00:00:00', freq='D'): 1603.7530000000002,
#   Timestamp('2021-02-24 00:00:00', freq='D'): 1644.144,
#   Timestamp('2021-02-25 00:00:00', freq='D'): 1688.277,
#   Timestamp('2021-02-26 00:00:00', freq='D'): 1722.8159999999998,
#   Timestamp('2021-02-27 00:00:00', freq='D'): 1761.9599999999998,
#   Timestamp('2021-02-28 00:00:00', freq='D'): 1820.196,
#   Timestamp('2021-03-01 00:00:00', freq='D'): 1865.6719999999998,
#   Timestamp('2021-03-02 00:00:00', freq='D'): 1983.7759999999998,
#   Timestamp('2021-03-03 00:00:00', freq='D'): 2170.189,
#   Timestamp('2021-03-04 00:00:00', freq='D'): 2248.573,
#   Timestamp('2021-03-05 00:00:00', freq='D'): 2320.145,
#   Timestamp('2021-03-06 00:00:00', freq='D'): 2404.2859999999996,
#   Timestamp('2021-03-09 00:00:00', freq='D'): 1353.1960000000001,
#   Timestamp('2021-03-10 00:00:00', freq='D'): 1416.65,
#   Timestamp('2021-03-11 00:00:00', freq='D'): 1475.862,
#   Timestamp('2021-03-12 00:00:00', freq='D'): 1546.141,
#   Timestamp('2021-03-13 00:00:00', freq='D'): 1655.341,
#   Timestamp('2021-03-14 00:00:00', freq='D'): 1740.192,
#   Timestamp('2021-03-15 00:00:00', freq='D'): 1765.279,
#   Timestamp('2021-03-16 00:00:00', freq='D'): 1885.3629999999998,
#   Timestamp('2021-03-17 00:00:00', freq='D'): 1954.535,
#   Timestamp('2021-03-18 00:00:00', freq='D'): 2040.124,
#   Timestamp('2021-03-19 00:00:00', freq='D'): 2095.278,
#   Timestamp('2021-03-20 00:00:00', freq='D'): 2179.576,
#   Timestamp('2021-03-21 00:00:00', freq='D'): 2212.963,
#   Timestamp('2021-03-22 00:00:00', freq='D'): 2262.398,
#   Timestamp('2021-03-23 00:00:00', freq='D'): 2330.833,
#   Timestamp('2021-03-24 00:00:00', freq='D'): 2385.9860000000003,
#   Timestamp('2021-03-25 00:00:00', freq='D'): 2378.4230000000002,
#   Timestamp('2021-03-26 00:00:00', freq='D'): 2409.228,
#   Timestamp('2021-03-27 00:00:00', freq='D'): 2336.92,
#   Timestamp('2021-03-28 00:00:00', freq='D'): 2344.483}}

# %%
cube
# Out:
#               Unnamed: 0                                        Afghanistan  \
# 0    2021-01-02 00:00:00  {'total_cases': 51526.0, 'new_cases': 0.0, 'to...
# 1    2021-01-03 00:00:00  {'total_cases': 51526.0, 'new_cases': 0.0, 'to...
# 2    2021-01-04 00:00:00  {'total_cases': 53011.0, 'new_cases': 1485.0, ...
# 3    2021-01-05 00:00:00  {'total_cases': 53105.0, 'new_cases': 94.0, 't...
# 4    2021-01-06 00:00:00  {'total_cases': 53105.0, 'new_cases': 0.0, 'to...
# ..                   ...                                                ...
# 219  2021-08-09 00:00:00  {'total_cases': 150778.0, 'new_cases': 968.0, ...
# 220  2021-08-10 00:00:00  {'total_cases': 151013.0, 'new_cases': 235.0, ...
# 221  2021-08-11 00:00:00  {'total_cases': 151291.0, 'new_cases': 278.0, ...
# 222           Population                                         38928341.0
# 223            Continent                                               Asia
#
#                                                 Africa  \
# 0    {'total_cases': 2811086.0, 'new_cases': 22919....
# 1    {'total_cases': 2833076.0, 'new_cases': 21990....
# 2    {'total_cases': 2854868.0, 'new_cases': 21792....
# 3    {'total_cases': 2881715.0, 'new_cases': 26847....
# 4    {'total_cases': 2917507.0, 'new_cases': 35792....
# ..                                                 ...
# 219  {'total_cases': 7048926.0, 'new_cases': 33595....
# 220  {'total_cases': 7083510.0, 'new_cases': 34584....
# 221  {'total_cases': 7117990.0, 'new_cases': 34480....
# 222                                       1340598113.0
# 223                                                NaN
#
#                                                Albania  \
# 0    {'total_cases': 58991.0, 'new_cases': 675.0, '...
# 1    {'total_cases': 59438.0, 'new_cases': 447.0, '...
# 2    {'total_cases': 59623.0, 'new_cases': 185.0, '...
# 3    {'total_cases': 60283.0, 'new_cases': 660.0, '...
# 4    {'total_cases': 61008.0, 'new_cases': 725.0, '...
# ..                                                 ...
# 219  {'total_cases': 133981.0, 'new_cases': 69.0, '...
# 220  {'total_cases': 134201.0, 'new_cases': 220.0, ...
# 221  {'total_cases': 134487.0, 'new_cases': 286.0, ...
# 222                                          2877800.0
# 223                                             Europe
#
#                                                Algeria  \
# 0    {'total_cases': 100159.0, 'new_cases': 262.0, ...
# 1    {'total_cases': 100408.0, 'new_cases': 249.0, ...
# 2    {'total_cases': 100645.0, 'new_cases': 237.0, ...
# 3    {'total_cases': 100873.0, 'new_cases': 228.0, ...
# 4    {'total_cases': 101120.0, 'new_cases': 247.0, ...
# ..                                                 ...
# 219  {'total_cases': 182368.0, 'new_cases': 992.0, ...
# 220  {'total_cases': 183347.0, 'new_cases': 979.0, ...
# 221  {'total_cases': 184191.0, 'new_cases': 844.0, ...
# 222                                         43851043.0
# 223                                             Africa
#
#                                                Andorra  \
# 0    {'total_cases': 8166.0, 'new_cases': 49.0, 'to...
# 1    {'total_cases': 8192.0, 'new_cases': 26.0, 'to...
# 2    {'total_cases': 8249.0, 'new_cases': 57.0, 'to...
# 3    {'total_cases': 8308.0, 'new_cases': 59.0, 'to...
# 4    {'total_cases': 8348.0, 'new_cases': 40.0, 'to...
# ..                                                 ...
# 219  {'total_cases': 14836.0, 'new_cases': 0.0, 'to...
# 220  {'total_cases': 14873.0, 'new_cases': 37.0, 't...
# 221  {'total_cases': 14891.0, 'new_cases': 18.0, 't...
# 222                                            77265.0
# 223                                             Europe
#
#                                                 Angola       Anguilla  \
# 0    {'total_cases': 17608.0, 'new_cases': 40.0, 't...            NaN
# 1    {'total_cases': 17642.0, 'new_cases': 34.0, 't...            NaN
# 2    {'total_cases': 17684.0, 'new_cases': 42.0, 't...            NaN
# 3    {'total_cases': 17756.0, 'new_cases': 72.0, 't...            NaN
# 4    {'total_cases': 17864.0, 'new_cases': 108.0, '...            NaN
# ..                                                 ...            ...
# 219  {'total_cases': 43747.0, 'new_cases': 85.0, 't...            NaN
# 220  {'total_cases': 43890.0, 'new_cases': 143.0, '...            NaN
# 221  {'total_cases': 43998.0, 'new_cases': 108.0, '...            NaN
# 222                                         32866268.0        15002.0
# 223                                             Africa  North America
#
#                                    Antigua and Barbuda  \
# 0    {'total_cases': 159.0, 'new_cases': 0.0, 'tota...
# 1    {'total_cases': 160.0, 'new_cases': 1.0, 'tota...
# 2    {'total_cases': 160.0, 'new_cases': 0.0, 'tota...
# 3    {'total_cases': 160.0, 'new_cases': 0.0, 'tota...
# 4    {'total_cases': 163.0, 'new_cases': 3.0, 'tota...
# ..                                                 ...
# 219  {'total_cases': 1348.0, 'new_cases': 10.0, 'to...
# 220  {'total_cases': 1348.0, 'new_cases': 0.0, 'tot...
# 221  {'total_cases': 1372.0, 'new_cases': 24.0, 'to...
# 222                                            97928.0
# 223                                      North America
#
#                                              Argentina  ...  \
# 0    {'total_cases': 1634834.0, 'new_cases': 5240.0...  ...
# 1    {'total_cases': 1640718.0, 'new_cases': 5884.0...  ...
# 2    {'total_cases': 1648940.0, 'new_cases': 8222.0...  ...
# 3    {'total_cases': 1662730.0, 'new_cases': 13790....  ...
# 4    {'total_cases': 1676171.0, 'new_cases': 13441....  ...
# ..                                                 ...  ...
# 219  {'total_cases': 5029075.0, 'new_cases': 10180....  ...
# 220  {'total_cases': 5041487.0, 'new_cases': 12412....  ...
# 221  {'total_cases': 5052884.0, 'new_cases': 11397....  ...
# 222                                         45195777.0  ...
# 223                                      South America  ...
#
#                                             Uzbekistan  \
# 0    {'total_cases': 77182.0, 'new_cases': 0.0, 'to...
# 1    {'total_cases': 77258.0, 'new_cases': 76.0, 't...
# 2    {'total_cases': 77258.0, 'new_cases': 0.0, 'to...
# 3    {'total_cases': 77295.0, 'new_cases': 37.0, 't...
# 4    {'total_cases': 77350.0, 'new_cases': 55.0, 't...
# ..                                                 ...
# 219  {'total_cases': 137491.0, 'new_cases': 856.0, ...
# 220  {'total_cases': 138382.0, 'new_cases': 891.0, ...
# 221  {'total_cases': 139285.0, 'new_cases': 903.0, ...
# 222                                         33469199.0
# 223                                               Asia
#
#                                                Vanuatu  \
# 0    {'total_cases': 1.0, 'new_cases': 0.0, 'total_...
# 1    {'total_cases': 1.0, 'new_cases': 0.0, 'total_...
# 2    {'total_cases': 1.0, 'new_cases': 0.0, 'total_...
# 3    {'total_cases': 1.0, 'new_cases': 0.0, 'total_...
# 4    {'total_cases': 1.0, 'new_cases': 0.0, 'total_...
# ..                                                 ...
# 219  {'total_cases': 4.0, 'new_cases': 0.0, 'total_...
# 220  {'total_cases': 4.0, 'new_cases': 0.0, 'total_...
# 221  {'total_cases': 4.0, 'new_cases': 0.0, 'total_...
# 222                                           307150.0
# 223                                            Oceania
#
#                                                Vatican  \
# 0    {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 1    {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 2    {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 3    {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 4    {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# ..                                                 ...
# 219  {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 220  {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 221  {'total_cases': 27.0, 'new_cases': 0.0, 'total...
# 222                                              809.0
# 223                                             Europe
#
#                                              Venezuela  \
# 0    {'total_cases': 114083.0, 'new_cases': 199.0, ...
# 1    {'total_cases': 114230.0, 'new_cases': 147.0, ...
# 2    {'total_cases': 114407.0, 'new_cases': 177.0, ...
# 3    {'total_cases': 114662.0, 'new_cases': 255.0, ...
# 4    {'total_cases': 114908.0, 'new_cases': 246.0, ...
# ..                                                 ...
# 219  {'total_cases': 312931.0, 'new_cases': 816.0, ...
# 220  {'total_cases': 314480.0, 'new_cases': 1549.0,...
# 221  {'total_cases': 314480.0, 'new_cases': 0.0, 't...
# 222                                         28435943.0
# 223                                      South America
#
#                                                Vietnam  \
# 0    {'total_cases': 1482.0, 'new_cases': 8.0, 'tot...
# 1    {'total_cases': 1494.0, 'new_cases': 12.0, 'to...
# 2    {'total_cases': 1497.0, 'new_cases': 3.0, 'tot...
# 3    {'total_cases': 1504.0, 'new_cases': 7.0, 'tot...
# 4    {'total_cases': 1505.0, 'new_cases': 1.0, 'tot...
# ..                                                 ...
# 219  {'total_cases': 224894.0, 'new_cases': 9334.0,...
# 220  {'total_cases': 232937.0, 'new_cases': 8043.0,...
# 221  {'total_cases': 241543.0, 'new_cases': 8606.0,...
# 222                                         97338583.0
# 223                                               Asia
#
#                                      Wallis and Futuna  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 219  {'total_cases': 0.0, 'new_cases': 0.0, 'total_...
# 220                                                NaN
# 221                                                NaN
# 222                                            11246.0
# 223                                            Oceania
#
#                                                  World  \
# 0    {'total_cases': 84728455.0, 'new_cases': 58980...
# 1    {'total_cases': 85255860.0, 'new_cases': 52740...
# 2    {'total_cases': 85809710.0, 'new_cases': 55385...
# 3    {'total_cases': 86549841.0, 'new_cases': 74013...
# 4    {'total_cases': 87333632.0, 'new_cases': 78379...
# ..                                                 ...
# 219  {'total_cases': 203384856.0, 'new_cases': 6566...
# 220  {'total_cases': 204022307.0, 'new_cases': 6374...
# 221  {'total_cases': 204729264.0, 'new_cases': 7069...
# 222                                       7794798729.0
# 223                                                NaN
#
#                                                  Yemen  \
# 0    {'total_cases': 2101.0, 'new_cases': 0.0, 'tot...
# 1    {'total_cases': 2101.0, 'new_cases': 0.0, 'tot...
# 2    {'total_cases': 2101.0, 'new_cases': 0.0, 'tot...
# 3    {'total_cases': 2101.0, 'new_cases': 0.0, 'tot...
# 4    {'total_cases': 2102.0, 'new_cases': 1.0, 'tot...
# ..                                                 ...
# 219  {'total_cases': 7187.0, 'new_cases': 22.0, 'to...
# 220  {'total_cases': 7198.0, 'new_cases': 11.0, 'to...
# 221  {'total_cases': 7213.0, 'new_cases': 15.0, 'to...
# 222                                         29825968.0
# 223                                               Asia
#
#                                                 Zambia  \
# 0    {'total_cases': 21230.0, 'new_cases': 233.0, '...
# 1    {'total_cases': 21582.0, 'new_cases': 352.0, '...
# 2    {'total_cases': 21993.0, 'new_cases': 411.0, '...
# 3    {'total_cases': 22645.0, 'new_cases': 652.0, '...
# 4    {'total_cases': 23495.0, 'new_cases': 850.0, '...
# ..                                                 ...
# 219  {'total_cases': 200201.0, 'new_cases': 152.0, ...
# 220  {'total_cases': 200830.0, 'new_cases': 629.0, ...
# 221  {'total_cases': 201342.0, 'new_cases': 512.0, ...
# 222                                         18383956.0
# 223                                             Africa
#
#                                               Zimbabwe
# 0    {'total_cases': 14491.0, 'new_cases': 407.0, '...
# 1    {'total_cases': 15265.0, 'new_cases': 774.0, '...
# 2    {'total_cases': 15829.0, 'new_cases': 564.0, '...
# 3    {'total_cases': 17194.0, 'new_cases': 1365.0, ...
# 4    {'total_cases': 17804.0, 'new_cases': 610.0, '...
# ..                                                 ...
# 219  {'total_cases': 116853.0, 'new_cases': 526.0, ...
# 220  {'total_cases': 117258.0, 'new_cases': 405.0, ...
# 221  {'total_cases': 117954.0, 'new_cases': 696.0, ...
# 222                                         14862927.0
# 223                                             Africa
#
# [224 rows x 233 columns]
